# %% [markdown]
# <a href="https://colab.research.google.com/github/AimanTabreez/PythonAssingment/blob/main/PythonAssingment(Aiman_Tabreez).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
a = int(input("Enter The Number:"))
b = int(input("Enter The Number:"))
def Addition(a,b):
    sum = a+b
    return sum
def Subtraction(a,b):
    sub = a-b
    return sub
def Multiplication(a,b):
    mul = a*b
    return mul
def Division(a,b):
    div = a/b
    return div
def Square(a):
    s = a**2
    return s
def SquareRoot(a):
    sr = math.sqrt(a)
    return sr
def x(a):
    n = 1/a
    return n
choice =1 
while choice!=0:
    print("0. Exit")
    print("1. Add")
    print("2. Subtraction")
    print("3. Multiplication")
    print("4. Division")
    print("5. Square")
    print("6. Square Root")
    print("7. 1/Any Number")

    choice=int(input("Enter choice: "))
    if choice==1:
        print(Addition(a,b))
    elif choice==2:
        print(Subtraction(a,b))
    elif choice==3:
        print(Multiplication(a,b))
    elif choice==4:
        print(Division(a,b))
    elif choice==5:
        print(Square(a))
    elif choice==6:
        print(SquareRoot(a))
    elif choice==7:
        print(x(a))
    elif choice==0:
        print("Exiting!")
    else:
        print("Invalid choice!")
# Out:
# Enter The Number:10
# Enter The Number:10
# 0. Exit
# 1. Add
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Square
# 6. Square Root
# 7. 1/Any Number
# Enter choice: 1
# 20
# 0. Exit
# 1. Add
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Square
# 6. Square Root
# 7. 1/Any Number
# Enter choice: 2
# 0
# 0. Exit
# 1. Add
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Square
# 6. Square Root
# 7. 1/Any Number
# Enter choice: 3
# 100
# 0. Exit
# 1. Add
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Square
# 6. Square Root
# 7. 1/Any Number
# Enter choice: 4
# 1.0
# 0. Exit
# 1. Add
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Square
# 6. Square Root
# 7. 1/Any Number
# Enter choice: 5
# 100
# 0. Exit
# 1. Add
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Square
# 6. Square Root
# 7. 1/Any Number
# Enter choice: 6
# 3.1622776601683795
# 0. Exit
# 1. Add
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Square
# ...
